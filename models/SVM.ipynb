# %%
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /home/cesar/.virtualenvs/T800/lib/python3.10/site-packages (0.17.1)
# Requirement already satisfied: packaging in /home/cesar/.virtualenvs/T800/lib/python3.10/site-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /home/cesar/.virtualenvs/T800/lib/python3.10/site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/cesar/.virtualenvs/T800/lib/python3.10/site-packages (from packaging->tensorflow-addons) (3.0.9)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, make_scorer, f1_score, roc_auc_score
import warnings
import tensorflow_addons as tfa
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./attack_dataset.csv") # attack dataset
attack_classes = pd.read_csv("./attack_labels.csv") # labels
bonafide = pd.read_csv('./bonafide_dataset_20191121.csv.gz') # bonafide dataset

df_labeled = df.merge(attack_classes, how='inner', left_on='ip.src', right_on='ip')
df_labeled.drop(['ip'], axis=1, inplace=True)
df_labeled.head(2)

bonafide['label'] = "bonafide" # create column label on bonafide dataset

if (df_labeled.columns == bonafide.columns).all():
    examples_attack = df_labeled.shape[0]
    examples_bonafide = bonafide.shape[0]
    total = examples_attack+examples_bonafide
    print('Total examples of {0} with {1:0.2f} of attack and {2:0.2f} bonafide packets'.format(total, examples_attack/total, examples_bonafide/total))
    
fields = ['eth.type', 'ip.id', 'ip.flags', 'ip.checksum', 'ip.dsfield', 'tcp.flags', 'tcp.checksum']

for field in fields:
    df_labeled[field] = df_labeled[field].apply(lambda x: int(str(x), 16))
    
bonafide = bonafide.fillna(0)
for field in fields:
    bonafide[field] = bonafide[field].apply(lambda x: int(str(x), 16))
    
full_data = pd.concat([bonafide, df_labeled])

wrong_proto = full_data[full_data['ip.proto'] != 6]['label'].value_counts().values
full_data = full_data[full_data['ip.proto'] == 6]

full_data.drop(columns=['frame_info.time', 'frame_info.encap_type', 'frame_info.time_epoch', 'frame_info.number', 
                        'frame_info.len', 'frame_info.cap_len', 'eth.type', 'ip.flags', 'ip.src', 'ip.dst',
                        'ip.version', 'ip.proto', 'tcp.flags'], axis=1, inplace=True)

# remove columns with zero variance
full_data.drop(columns=['ip.hdr_len', 'ip.tos', 'ip.flags.rb', 
                        'ip.flags.mf', 'ip.frag_offset'], axis=1, inplace=True)

# It is removed ttl because previous attempt shows that it is learning the LAN architecture TTL=62
# (from scan tools TTL=64 minus 2 routers in the infrastructure)

# sequence, checksum and acknowledge features because they are random

# removed source and destination ports to be agnostic regarding the service ports

# removed tcp.options.mss_val because it is dificult to be retrieved as LKM

# removed tcp.window_size to allow running iperf on ESP32 and to reduce false positives

full_data.drop(columns=["ip.checksum", "ip.ttl", "tcp.checksum", "tcp.dstport", "tcp.seq", "tcp.srcport", 
                        "tcp.ack", "tcp.options.mss_val", "tcp.window_size"], axis=1, inplace=True)

full_data.info()
# Out:
# Total examples of 140163 with 0.26 of attack and 0.74 bonafide packets
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128455 entries, 1 to 37068
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ip.id               128455 non-null  int64
#  1   ip.flags.df         128455 non-null  float64
#  2   ip.len              128455 non-null  float64
#  3   ip.dsfield          128455 non-null  int64
#  4   tcp.len             128455 non-null  float64
#  5   tcp.hdr_len         128455 non-null  float64
#  6   tcp.flags.fin       128455 non-null  float64
#  7   tcp.flags.syn       128455 non-null  float64
#  8   tcp.flags.reset     128455 non-null  float64
#  9   tcp.flags.push      128455 non-null  float64
#  10  tcp.flags.ack       128455 non-null  float64
#  11  tcp.flags.urg       128455 non-null  float64
#  12  tcp.flags.cwr       128455 non-null  float64
#  13  tcp.urgent_pointer  128455 non-null  float64
#  14  label               128455 non-null  object
# dtypes: float64(12), int64(2), object(1)
# memory usage: 15.7+ MB

# %%
full_data.label[full_data.label == "bonafide"] = -1 # convert bonafide label to 0
full_data.label[full_data.label != 0] = 1 # convert attack labels to 1
full_data['label'].value_counts()

full_data = full_data.fillna(0)
X = full_data.drop(columns = ["label"])
y = full_data.label

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train)

# %%
class Sign(tf.keras.layers.Layer):
  def __init__(self):
    super(Sign, self).__init__()
    
  def call(self, inputs):
    return tf.sign(inputs)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_shape=(x_train.shape[1],), use_bias=True, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    Sign()
])
model.compile(loss='hinge',
              optimizer='adadelta',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 15
#
#  sign (Sign)                 (None, 1)                 0
#
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
# 2022-08-12 10:10:46.601784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 10:10:46.653539: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-08-12 10:10:46.653568: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-08-12 10:10:46.654123: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_ds = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(256)
val_ds = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(1024)

# %%
history = model.fit(train_ds, validation_data=val_ds, epochs=1000)
# Out:
# Epoch 1/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9462 - accuracy: 0.0317 - val_loss: 1.9464 - val_accuracy: 0.0316
# Epoch 2/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9462 - accuracy: 0.0317 - val_loss: 1.9464 - val_accuracy: 0.0316
# Epoch 3/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9461 - accuracy: 0.0317 - val_loss: 1.9463 - val_accuracy: 0.0316
# Epoch 4/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9461 - accuracy: 0.0317 - val_loss: 1.9463 - val_accuracy: 0.0316
# Epoch 5/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9460 - accuracy: 0.0317 - val_loss: 1.9462 - val_accuracy: 0.0316
# Epoch 6/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9459 - accuracy: 0.0317 - val_loss: 1.9462 - val_accuracy: 0.0316
# Epoch 7/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9459 - accuracy: 0.0317 - val_loss: 1.9462 - val_accuracy: 0.0315
# Epoch 8/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9458 - accuracy: 0.0317 - val_loss: 1.9461 - val_accuracy: 0.0315
# Epoch 9/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9458 - accuracy: 0.0317 - val_loss: 1.9461 - val_accuracy: 0.0315
# Epoch 10/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9457 - accuracy: 0.0317 - val_loss: 1.9460 - val_accuracy: 0.0315
# Epoch 11/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9456 - accuracy: 0.0317 - val_loss: 1.9459 - val_accuracy: 0.0315
# Epoch 12/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9455 - accuracy: 0.0317 - val_loss: 1.9459 - val_accuracy: 0.0315
# Epoch 13/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9455 - accuracy: 0.0317 - val_loss: 1.9459 - val_accuracy: 0.0315
# Epoch 14/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9454 - accuracy: 0.0317 - val_loss: 1.9458 - val_accuracy: 0.0315
# Epoch 15/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9453 - accuracy: 0.0317 - val_loss: 1.9457 - val_accuracy: 0.0315
# Epoch 16/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9452 - accuracy: 0.0317 - val_loss: 1.9457 - val_accuracy: 0.0315
# Epoch 17/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9452 - accuracy: 0.0317 - val_loss: 1.9456 - val_accuracy: 0.0315
# Epoch 18/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.
1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 893/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 894/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 895/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 896/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 897/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 898/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 899/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 900/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 901/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 902/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 903/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 904/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 905/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 906/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 907/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 908/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 909/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 910/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 911/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 912/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 913/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 914/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 915/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 916/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 917/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 918/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 919/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 920/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 921/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 922/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 923/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 924/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 925/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 926/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 927/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 928/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 929/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 930/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 931/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 932/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 933/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 934/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 935/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 936/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 937/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 938/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 939/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 940/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 941/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 942/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 943/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 944/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 945/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 946/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 947/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 948/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 949/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 950/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 951/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 952/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 953/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 954/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 955/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 956/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 957/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 958/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 959/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 960/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 961/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 962/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 963/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 964/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 965/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 966/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 967/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 968/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 969/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 970/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 971/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 972/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 973/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 974/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 975/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 976/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 977/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 978/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 979/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 980/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 981/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 982/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 983/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 984/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 985/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 986/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 987/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 988/1000
# 322/322 [==============================] - 1s 4ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 989/1000
# 322/322 [==============================] - 1s 2ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 990/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 991/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 992/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 993/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 994/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 995/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 996/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 997/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 998/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 999/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313
# Epoch 1000/1000
# 322/322 [==============================] - 1s 3ms/step - loss: 1.9370 - accuracy: 0.0315 - val_loss: 1.9373 - val_accuracy: 0.0313

# %%
mlp_pred = (model.predict(x_test) > 0.5).astype(np.int32)
print(f1_score(y_test, mlp_pred))
# Out:
# 803/803 [==============================] - 1s 2ms/step
# 0.06259190829908375

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('svm.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp64bfi3me/assets
# 2022-08-12 10:23:32.439459: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2022-08-12 10:23:32.439490: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2022-08-12 10:23:32.440156: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /tmp/tmp64bfi3me
# 2022-08-12 10:23:32.440958: I tensorflow/cc/saved_model/reader.cc:81] Reading meta graph with tags { serve }
# 2022-08-12 10:23:32.440974: I tensorflow/cc/saved_model/reader.cc:122] Reading SavedModel debug info (if present) from: /tmp/tmp64bfi3me
# 2022-08-12 10:23:32.444504: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2022-08-12 10:23:32.445381: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2022-08-12 10:23:32.475423: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /tmp/tmp64bfi3me
# 2022-08-12 10:23:32.488481: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 48323 microseconds.
# 2022-08-12 10:23:32.505082: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:263] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# loc(callsite(callsite(fused["Sign:", callsite("sequential/sign/Sign@__inference__wrapped_model_1395189"("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py":1082:0) at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py":150:0 at callsite("/tmp/ipykernel_245566/3757721691.py":6:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/keras/utils/traceback_utils.py":92:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/keras/engine/base_layer.py":1014:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/keras/utils/traceback_utils.py":64:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/keras/engine/functional.py":596:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/keras/engine/functional.py":458:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/keras/engine/sequential.py":374:0 at "/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/keras/utils/traceback_utils.py":92:0)))))))))] at fused["StatefulPartitionedCall:", callsite("StatefulPartitionedCall@__inference_signature_wrapper_1395351"("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/python/saved_model/save.py":1325:0) at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/python/saved_model/save.py":1290:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py":1248:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/convert_phase.py":205:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py":1318:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py":1338:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py":908:0 at callsite("/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py":929:0 at callsite("/tmp/ipykernel_245566/2809005982.py":2:0 at "/home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/IPython/core/interactiveshell.py":3398:0)))))))))]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall"])): error: 'tf.Sign' op is neither a custom op nor a flex op
# error: failed while converting: 'main':
# Some ops are not supported by the native TFLite runtime, you can enable TF kernels fallback using TF Select. See instructions: https://www.tensorflow.org/lite/guide/ops_select
# TF Select ops: Sign
# Details:
# 	tf.Sign(tensor<?x1xf32>) -> (tensor<?x1xf32>) : {device = ""}
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 converter = tf.lite.TFLiteConverter.from_keras_model(model)
# ----> 2 tflite_model = converter.convert()
#       4 # Save the model.
#       5 with open('svm.tflite', 'wb') as f:
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:929, in _export_metrics.<locals>.wrapper(self, *args, **kwargs)
#     926 @functools.wraps(convert_func)
#     927 def wrapper(self, *args, **kwargs):
#     928   # pylint: disable=protected-access
# --> 929   return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:908, in TFLiteConverterBase._convert_and_export_metrics(self, convert_func, *args, **kwargs)
#     906 self._save_conversion_params_metric()
#     907 start_time = time.process_time()
# --> 908 result = convert_func(self, *args, **kwargs)
#     909 elapsed_time_ms = (time.process_time() - start_time) * 1000
#     910 if result:
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1338, in TFLiteKerasModelConverterV2.convert(self)
#    1325 @_export_metrics
#    1326 def convert(self):
#    1327   """Converts a keras model based on instance variables.
#    1328
#    1329   Returns:
#    (...)
#    1336       Invalid quantization parameters.
#    1337   """
# -> 1338   saved_model_convert_result = self._convert_as_saved_model()
#    1339   if saved_model_convert_result:
#    1340     return saved_model_convert_result
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1321, in TFLiteKerasModelConverterV2._convert_as_saved_model(self)
#    1317   graph_def, input_tensors, output_tensors = (
#    1318       self._convert_keras_to_saved_model(temp_dir))
#    1319   if self.saved_model_dir:
#    1320     return super(TFLiteKerasModelConverterV2,
# -> 1321                  self).convert(graph_def, input_tensors, output_tensors)
#    1322 finally:
#    1323   shutil.rmtree(temp_dir, True)
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1131, in TFLiteConverterBaseV2.convert(self, graph_def, input_tensors, output_tensors)
#    1126   logging.info("Using new converter: If you encounter a problem "
#    1127                "please file a bug. You can opt-out "
#    1128                "by setting experimental_new_converter=False")
#    1130 # Converts model.
# -> 1131 result = _convert_graphdef(
#    1132     input_data=graph_def,
#    1133     input_tensors=input_tensors,
#    1134     output_tensors=output_tensors,
#    1135     **converter_kwargs)
#    1137 return self._optimize_tflite_model(
#    1138     result, self._quant_mode, quant_io=self.experimental_new_quantizer)
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/convert_phase.py:212, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     210   else:
#     211     report_error_message(str(converter_error))
# --> 212   raise converter_error from None  # Re-throws the exception.
#     213 except Exception as error:
#     214   report_error_message(str(error))
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:794, in convert_graphdef(input_data, input_tensors, output_tensors, **kwargs)
#     791   else:
#     792     model_flags.output_arrays.append(util.get_tensor_name(output_tensor))
# --> 794 data = convert(
#     795     model_flags.SerializeToString(),
#     796     conversion_flags.SerializeToString(),
#     797     input_data.SerializeToString(),
#     798     debug_info_str=debug_info.SerializeToString() if debug_info else None,
#     799     enable_mlir_converter=enable_mlir_converter)
#     800 return data
#
# File ~/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:311, in convert(model_flags_str, conversion_flags_str, input_data_str, debug_info_str, enable_mlir_converter)
#     309     for error_data in _metrics_wrapper.retrieve_collected_errors():
#     310       converter_error.append_error(error_data)
# --> 311     raise converter_error
#     313 return _run_deprecated_conversion_binary(model_flags_str,
#     314                                          conversion_flags_str, input_data_str,
#     315                                          debug_info_str)
#
# ConverterError: /home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1082:0: error: 'tf.Sign' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall"]): called from
# /home/cesar/.virtualenvs/T800/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1082:0: note: Error code: ERROR_NEEDS_FLEX_OPS
# <unknown>:0: error: failed while converting: 'main':
# Some ops are not supported by the native TFLite runtime, you can enable TF kernels fallback using TF Select. See instructions: https://www.tensorflow.org/lite/guide/ops_select
# TF Select ops: Sign
# Details:
# 	tf.Sign(tensor<?x1xf32>) -> (tensor<?x1xf32>) : {device = ""}
